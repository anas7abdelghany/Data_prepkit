# %%
import numpy as np 
import pandas as pd

class Dataprepkit:
    def __init__(self):
        self.data = None
    
    def read_data(self, file_path, file_format):
    
        try:
            if file_format == 'csv':
                self.data = pd.read_csv(file_path)
            elif file_format == 'excel':
                self.data = pd.read_excel(file_path)
            elif file_format == 'json':
                self.data = pd.read_json(file_path)
            else:
                raise ValueError("Unsupported file format")
                
        except Exception as e:
            print(f"Error reading file: {str(e)}")
            
    
    def gen_summary(self):
        if self.data is not None:
            return self.data.describe()
        else:
            print("No data available.")
            
    def most_frequent_values(self):
        if self.data is not None:
            return self.data.mode().iloc[0]
        else:
            print("No data available.")
            
            
            
    
    def handle_missing_values(self, handling_Type):
        try:
            if handling_Type == 'mean':
                return self.data.fillna(self.data.mean())
            elif handling_Type == 'median':
                return self.data.fillna(self.data.median())
            elif handling_Type == 'drop':
                return self.data.dropna()
            else:
                raise ValueError("Unsupported missing value handling strategy")
        except Exception as e:
            print(f"Error handling missing values: {str(e)}")
            
            
    
    def one_hot_encoding(self, columns):
        if self.data is not None:
            return pd.get_dummies(self.data, columns=columns)
        else:
            print("No data available.")
    
    def label_encoding(self, column):
        if self.data is not None:
            labels = self.data[column].astype('category').cat.codes
            return labels
        else:
            print("No data available.")
            
            

file_path = input("Enter your file path: ")
file_format = input("Enter the file format: ")
obj = Dataprepkit()
obj.read_data(file_path , file_format)
# Out:
# Enter your file path: E:\term 2\Data Analysis\Amgad\Lect 2- Descriptive Statistics\Flavors.csv
# Enter the file format: csv

# %%
obj.data
# Out:
#                    Flavor Base Flavor Liked  Flavor Rating  Texture Rating  \
# 0     Mint Chocolate Chip     Vanilla   Yes           10.0             8.0
# 1               Chocolate   Chocolate   Yes            8.8             7.6
# 2                 Vanilla     Vanilla    No            4.7             5.0
# 3            Cookie Dough     Vanilla   Yes            6.9             6.5
# 4              Rocky Road   Chocolate   Yes            8.2             7.0
# 5               Pistachio     Vanilla    No            2.3             NaN
# 6             Cake Batter     Vanilla   Yes            6.5             6.0
# 7              Neapolitan     Vanilla    No            3.8             5.0
# 8  Chocolte Fudge Brownie   Chocolate   Yes            8.2             7.1
#
#    Total Rating
# 0          18.0
# 1          16.6
# 2           9.7
# 3          13.4
# 4          15.2
# 5           5.7
# 6          12.5
# 7           8.8
# 8          15.3

# %%
obj.gen_summary()
# Out:
#        Flavor Rating  Texture Rating  Total Rating
# count         9.0000        8.000000      9.000000
# mean          6.6000        6.525000     12.800000
# std           2.5387        1.122179      4.030509
# min           2.3000        5.000000      5.700000
# 25%           4.7000        5.750000      9.700000
# 50%           6.9000        6.750000     13.400000
# 75%           8.2000        7.225000     15.300000
# max          10.0000        8.000000     18.000000

# %%
obj.most_frequent_values()
# Out:
# Flavor            Cake Batter
# Base Flavor           Vanilla
# Liked                     Yes
# Flavor Rating             8.2
# Texture Rating            5.0
# Total Rating              5.7
# Name: 0, dtype: object

# %%
obj.handle_missing_values('mean')
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_1048\529560308.py:42: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   return self.data.fillna(self.data.mean())
#                    Flavor Base Flavor Liked  Flavor Rating  Texture Rating  \
# 0     Mint Chocolate Chip     Vanilla   Yes           10.0           8.000
# 1               Chocolate   Chocolate   Yes            8.8           7.600
# 2                 Vanilla     Vanilla    No            4.7           5.000
# 3            Cookie Dough     Vanilla   Yes            6.9           6.500
# 4              Rocky Road   Chocolate   Yes            8.2           7.000
# 5               Pistachio     Vanilla    No            2.3           6.525
# 6             Cake Batter     Vanilla   Yes            6.5           6.000
# 7              Neapolitan     Vanilla    No            3.8           5.000
# 8  Chocolte Fudge Brownie   Chocolate   Yes            8.2           7.100
#
#    Total Rating
# 0          18.0
# 1          16.6
# 2           9.7
# 3          13.4
# 4          15.2
# 5           5.7
# 6          12.5
# 7           8.8
# 8          15.3

# %%
obj.label_encoding('Liked')
# Out:
# 0    1
# 1    1
# 2    0
# 3    1
# 4    1
# 5    0
# 6    1
# 7    0
# 8    1
# dtype: int8

# %%
obj.one_hot_encoding(['Base Flavor'])
# Out:
#                    Flavor Liked  Flavor Rating  Texture Rating  Total Rating  \
# 0     Mint Chocolate Chip   Yes           10.0             8.0          18.0
# 1               Chocolate   Yes            8.8             7.6          16.6
# 2                 Vanilla    No            4.7             5.0           9.7
# 3            Cookie Dough   Yes            6.9             6.5          13.4
# 4              Rocky Road   Yes            8.2             7.0          15.2
# 5               Pistachio    No            2.3             NaN           5.7
# 6             Cake Batter   Yes            6.5             6.0          12.5
# 7              Neapolitan    No            3.8             5.0           8.8
# 8  Chocolte Fudge Brownie   Yes            8.2             7.1          15.3
#
#    Base Flavor_Chocolate  Base Flavor_Vanilla
# 0                      0                    1
# 1                      1                    0
# 2                      0                    1
# 3                      0                    1
# 4                      1                    0
# 5                      0                    1
# 6                      0                    1
# 7                      0                    1
# 8                      1                    0
